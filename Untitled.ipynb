# %%
# basic toolkit for the workflow
import pandas as pd
import data_tools as dt
import clustering as cl
import feature_selection_single as fss
import feature_selection_multi as fsm
import cross_validation as cv
import export_model as em

# %%
# in this example, the last column is the response variable (log10 of LD50)
# we use pandas to manipulate the data
dfx = pd.DataFrame(pd.read_csv('28BenzeneDescriptors.csv')).iloc[:,:-1]
dfy = pd.DataFrame(pd.read_csv('28BenzeneDescriptors.csv')).iloc[:,-1]

# %%
dfx.head()
# Out:
#    No.    AMW      Sp     Mv     Me     Ms  nBM    ARR  RBN    RBF  ...  \
# 0    1  6.510   8.284  0.649  0.971  2.000    6  1.000    0  0.000  ...
# 1    2  6.143  10.045  0.626  0.969  1.952    6  0.857    1  0.067  ...
# 2    3  8.794   9.438  0.658  1.037  3.074    8  0.889    1  0.071  ...
# 3    4  8.068  11.199  0.636  1.024  2.933    8  0.800    2  0.118  ...
# 4    5  8.068  11.199  0.636  1.024  2.933    8  0.800    2  0.118  ...
#
#     PCWTe    LDI     Hy     AMR  MLOGP  MLOGP2  ALOGP  GVWAI-80  Infective-80  \
# 0  10.100  0.062 -0.921  26.058  2.255   5.085  2.047         0             0
# 1  11.371  0.057 -0.936  31.099  2.608   6.802  2.514         0             0
# 2   2.209  0.144 -0.636  33.383  1.797   3.229  2.000         0             0
# 3   2.441  0.130 -0.672  38.424  2.150   4.623  2.467         0             0
# 4   2.313  0.123 -0.672  38.424  2.150   4.623  2.467         0             0
#
#    BLTD48
# 0   -3.46
# 1   -3.80
# 2   -3.03
# 3   -3.36
# 4   -3.36
#
# [5 rows x 676 columns]

# %%
dfx.shape
# Out:
# (28, 676)

# %%
# we can use various data tools to reshape x 
dfx = dt.rm_constant(dfx)
dfx = dt.rm_nan(dfx)
dfx = dt.train_scale(dfx)
dfx.shape
# Out:
# (28, 676)

# %%
# there is also an option to do all of the above as one process
# and also to use a cutoff for autocorrelation of X variables
# while also outputting the autocorrelation matrix 
dfx = pd.DataFrame(pd.read_csv('28BenzeneDescriptors.csv')).iloc[:,:-1]
dfx2 = dt.clean_data(dfx, cutoff=None, plot=True)

# %%
dfx2.shape
# Out:
# (28, 676)

# %%
# create training-test split sorted by response variable 
xtrain, xtest, ytrain, ytest = dt.sorted_split(dfx,dfy,0.2)
# similiarly, dt.random_split(x,y,test_size=n) also works for larger datasets

# %%
# creates a feature cluster with 'average' euclidean distance and cutoff of 2
# this is the tunable part of the system 
clust = cl.featureCluster(xtrain, 'average', 2)

# %%
# export the results of the clustering, returning the dictionary we will use later
# optionally, print out everything
# optionally, also graph a dendogram (mostly for tuning rather than visualization)
clusterinfo = clust.set_cluster(verbose=True, graph=False)
# Out:
#  Cluster 1 ['ATS6m', 'Ts']
#
#  Cluster 2 ['EEig02x']
#
#  Cluster 3 ['IDE', 'HVcpx']
#
#  Cluster 4 ['DP12', 'DP14', 'SP15']
#
#  Cluster 5 ['BAC', 'EEig03x']
#
#  Cluster 6 ['Av']
#
#  Cluster 7 ['SPI']
#
#  Cluster 8 ['QXXv', 'L2v']
#
#  Cluster 9 ['L2m']
#
#  Cluster 10 ['Infective-80']
#
#  Cluster 11 ['EEig14d']
#
#  Cluster 12 ['HATS6v', 'HATS6p']
#
#  Cluster 13 ['Mor30m']
#
#  Cluster 14 ['R6m']
#
#  Cluster 15 ['CENT', 'X5', 'EEig06x', 'As']
#
#  Cluster 16 ['Mor03u', 'Mor03e']
#
#  Cluster 17 ['Mor08v']
#
#  Cluster 18 ['RDF060m', 'L2s']
#
#  Cluster 19 ['PW5']
#
#  Cluster 20 ['E2s']
#
#  Cluster 21 ['X4A', 'GGI1']
#
#  Cluster 22 ['LPRS', 'CSI', 'VAR', 'MPC06']
#
#  Cluster 23 ['VED2', 'DP03']
#
#  Cluster 24 ['SEige']
#
#  Cluster 25 ['EEig07x', 'EEig07r', 'BEHv8']
#
#  Cluster 26 ['ITH']
#
#  Cluster 27 ['X3A']
#
#  Cluster 28 ['ATS3p']
#
#  Cluster 29 ['RDF040u']
#
#  Cluster 30 ['Mor27v']
#
#  Cluster 31 ['X3v', 'HTv']
#
#  Cluster 32 ['X5v']
#
#  Cluster 33 ['H2v']
#
#  Cluster 34 ['H3v']
#
#  Cluster 35 ['ATS3m']
#
#  Cluster 36 ['BEHm4']
#
#  Cluster 37 ['BEHm3']
#
#  Cluster 38 ['PW3', 'X2A']
#
#  Cluster 39 ['X1v', 'X3sol', 'X4sol', 'nCaH', 'nCa-']
#
#  Cluster 40 ['Mor03v', 'H2m']
#
#  Cluster 41 ['H3e']
#
#  Cluster 42 ['SEigZ', 'Mor03p', 'H1m']
#
#  Cluster 43 ['C-026']
#
#  Cluster 44 ['Mor03m']
#
#  Cluster 45 ['E2m']
#
#  Cluster 46 ['JhetZ']
#
#  Cluster 47 ['H-047']
#
#  Cluster 48 ['MSD', 'J', 'Jhete', 'Mor05m']
#
#  Cluster 49 ['QXXp']
#
#  Cluster 50 ['GGI3']
#
#  Cluster 51 ['QXXm']
#
#  Cluster 52 ['S2K', 'X2sol', 'EEig03d', 'EEig06d']
#
#  Cluster 53 ['GGI4', 'Am']
#
#  Cluster 54 ['No.', 'SRW10', 'X4', 'BEHm8', 'GGI2']
#
#  Cluster 55 ['ESpm03u', 'ESpm09u']
#
#  Cluster 56 ['X5A', 'EEig05d', 'ESpm02d']
#
#  Cluster 57 ['ATS5m']
#
#  Cluster 58 ['GNar', 'PW2', 'EEig01x', 'EEig07d']
#
#  Cluster 59 ['BEHm5', 'BEHm7']
#
#  Cluster 60 ['ATS1m', 'ATS4m', 'EEig04d']
#
#  Cluster 61 ['PHI', 'X5sol', 'BEHm6', 'QZZm']
#
#  Cluster 62 ['AMR']
#
#  Cluster 63 ['S3K', 'Tm']
#
#  Cluster 64 ['JGI1']
#
#  Cluster 65 ['JGT']
#
#  Cluster 66 ['S0K']
#
#  Cluster 67 ['ESpm03d', 'ESpm08d']
#
#  Cluster 68 ['EEig02d']
#
#  Cluster 69 ['JGI2']
#
#  Cluster 70 ['QYYm']
#
#  Cluster 71 ['Me']
#
#  Cluster 72 ['Mor25u']
#
#  Cluster 73 ['HATS6m']
#
#  Cluster 74 ['RCI']
#
#  Cluster 75 ['Mor30p']
#
#  Cluster 76 ['ATS4v', 'QZZv', 'Mor01v']
#
#  Cluster 77 ['Mor05v']
#
#  Cluster 78 ['R5v']
#
#  Cluster 79 ['R5p']
#
#  Cluster 80 ['Mor23u', 'Mor23v']
#
#  Cluster 81 ['Sp', 'ATS3v', 'Tp']
#
#  Cluster 82 ['BEHp8']
#
#  Cluster 83 ['MATS2v']
#
#  Cluster 84 ['MATS2p']
#
#  Cluster 85 ['HOMA']
#
#  Cluster 86 ['PW4']
#
#  Cluster 87 ['QYYv']
#
#  Cluster 88 ['QYYp']
#
#  Cluster 89 ['SPAN']
#
#  Cluster 90 ['BELv7', 'BELp7']
#
#  Cluster 91 ['GVWAI-80']
#
#  Cluster 92 ['BEHv7']
#
#  Cluster 93 ['BEHe7']
#
#  Cluster 94 ['H5u', 'R5u']
#
#  Cluster 95 ['MATS2m']
#
#  Cluster 96 ['BEHv2']
#
#  Cluster 97 ['BEHv4']
#
#  Cluster 98 ['QYYe']
#
#  Cluster 99 ['TIC2']
#
#  Cluster 100 ['TIC3']
#
#  Cluster 101 ['TIC1']
#
#  Cluster 102 ['RTe']
#
#  Cluster 103 ['BELm7']
#
#  Cluster 104 ['RDF070u', 'RDF070v']
#
#  Cluster 105 ['Mor04u']
#
#  Cluster 106 ['Mor25m']
#
#  Cluster 107 ['R2u+']
#
#  Cluster 108 ['BELv2', 'BELv5']
#
#  Cluster 109 ['RBN', 'RBF', 'BEHe5']
#
#  Cluster 110 ['RDF025v', 'H4u']
#
#  Cluster 111 ['HIC', 'HTu']
#
#  Cluster 112 ['ATS5e', 'BELe5', 'SEig', 'RDF015m']
#
#  Cluster 113 ['BEHe4']
#
#  Cluster 114 ['BELv3']
#
#  Cluster 115 ['BELe3']
#
#  Cluster 116 ['HATS0u']
#
#  Cluster 117 ['BELe6']
#
#  Cluster 118 ['H2e']
#
#  Cluster 119 ['BELv6', 'HGM']
#
#  Cluster 120 ['ATS6e', 'RDF050u', 'RDF025m', 'HATS4u']
#
#  Cluster 121 ['RDF050m', 'RDF050p']
#
#  Cluster 122 ['BEHe3', 'R6u', 'R6e']
#
#  Cluster 123 ['H1e']
#
#  Cluster 124 ['TE1']
#
#  Cluster 125 ['RDF070m']
#
#  Cluster 126 ['Mor24v']
#
#  Cluster 127 ['HATS2u']
#
#  Cluster 128 ['T(N..N)', 'T(N..O)']
#
#  Cluster 129 ['RDF060u']
#
#  Cluster 130 ['nO', 'SEigv', 'Qpos']
#
#  Cluster 131 ['nBM', 'ZM2V', 'GMTIV', 'PCR', 'GGI5']
#
#  Cluster 132 ['HOMT']
#
#  Cluster 133 ['HATS6u', 'HATS6e']
#
#  Cluster 134 ['EEig09x']
#
#  Cluster 135 ['BEHe8']
#
#  Cluster 136 ['MPC08', 'RDF060v', 'L2u']
#
#  Cluster 137 ['BEHv3', 'QXXe']
#
#  Cluster 138 ['BEHv6']
#
#  Cluster 139 ['R3u']
#
#  Cluster 140 ['Mor32v']
#
#  Cluster 141 ['EEig13x']
#
#  Cluster 142 ['Mor27u']
#
#  Cluster 143 ['IAC']
#
#  Cluster 144 ['BEHe2']
#
#  Cluster 145 ['MPC07', 'ESpm01r', 'AEigm']
#
#  Cluster 146 ['EEig05x']
#
#  Cluster 147 ['EEig08x']
#
#  Cluster 148 ['RGyr']
#
#  Cluster 149 ['Mor25v']
#
#  Cluster 150 ['Mor30v']
#
#  Cluster 151 ['EEig08r']
#
#  Cluster 152 ['R4u+']
#
#  Cluster 153 ['BEHv1', 'H4v']
#
#  Cluster 154 ['ATS5v', 'Au']
#
#  Cluster 155 ['ATS6v', 'ATS3e', 'ATS6p', 'QZZe', 'Tu']
#
#  Cluster 156 ['BEHv5']
#
#  Cluster 157 ['BEHe6', 'Mor05u']
#
#  Cluster 158 ['HTe', 'R6v', 'R6p']
#
#  Cluster 159 ['Mor04v']
#
#  Cluster 160 ['ICR']
#
#  Cluster 161 ['E1s']
#
#  Cluster 162 ['L1m']
#
#  Cluster 163 ['L1s']
#
#  Cluster 164 ['TI2']
#
#  Cluster 165 ['JGI5']
#
#  Cluster 166 ['Vindex']
#
#  Cluster 167 ['Yindex']
#
#  Cluster 168 ['Lop']
#
#  Cluster 169 ['GATS7p', 'R7m']
#
#  Cluster 170 ['GGI6']
#
#  Cluster 171 ['DECC']
#
#  Cluster 172 ['HATS7v', 'R7v+']
#
#  Cluster 173 ['HATS7u', 'HATS7e', 'R7v']
#
#  Cluster 174 ['L1u', 'L1e']
#
#  Cluster 175 ['ATS7m', 'ATS7v', 'ATS7p']
#
#  Cluster 176 ['R7u+']
#
#  Cluster 177 ['GATS7v']
#
#  Cluster 178 ['MATS7v', 'MATS7p']
#
#  Cluster 179 ['GATS7m']
#
#  Cluster 180 ['GATS7e']
#
#  Cluster 181 ['E3s']
#
#  Cluster 182 ['DP18']
#
#  Cluster 183 ['H3u']
#
#  Cluster 184 ['RDF065u', 'RDF065v']
#
#  Cluster 185 ['L1v', 'L1p']
#
#  Cluster 186 ['RDF065m']
#
#  Cluster 187 ['EEig11d']
#
#  Cluster 188 ['EEig11r']
#
#  Cluster 189 ['JGI3']
#
#  Cluster 190 ['HATS5e']
#
#  Cluster 191 ['IDDE']
#
#  Cluster 192 ['L3m']
#
#  Cluster 193 ['L3v']
#
#  Cluster 194 ['SPH', 'L3u']
#
#  Cluster 195 ['RDF055u']
#
#  Cluster 196 ['MATS4p']
#
#  Cluster 197 ['RDF030p']
#
#  Cluster 198 ['RDF030u']
#
#  Cluster 199 ['MATS4v']
#
#  Cluster 200 ['RDF045u']
#
#  Cluster 201 ['RDF055e']
#
#  Cluster 202 ['L3s']
#
#  Cluster 203 ['EEig09r']
#
#  Cluster 204 ['RPCG']
#
#  Cluster 205 ['R2p+']
#
#  Cluster 206 ['R1v+']
#
#  Cluster 207 ['R1p+']
#
#  Cluster 208 ['E2e']
#
#  Cluster 209 ['Mor30u']
#
#  Cluster 210 ['Mor30e']
#
#  Cluster 211 ['EEig10x']
#
#  Cluster 212 ['EEig15d']
#
#  Cluster 213 ['MATS1e']
#
#  Cluster 214 ['RTu+']
#
#  Cluster 215 ['H6u', 'H6m', 'H6v']
#
#  Cluster 216 ['E3u']
#
#  Cluster 217 ['MATS1m']
#
#  Cluster 218 ['Mor22u']
#
#  Cluster 219 ['Mor22e']
#
#  Cluster 220 ['E3m']
#
#  Cluster 221 ['HATS5u']
#
#  Cluster 222 ['MATS5m']
#
#  Cluster 223 ['MATS5e']
#
#  Cluster 224 ['E3v']
#
#  Cluster 225 ['E3p']
#
#  Cluster 226 ['GATS1e']
#
#  Cluster 227 ['Mor32m']
#
#  Cluster 228 ['E3e']
#
#  Cluster 229 ['De']
#
#  Cluster 230 ['G1v']
#
#  Cluster 231 ['MATS3m']
#
#  Cluster 232 ['JGI4']
#
#  Cluster 233 ['nOHPh']
#
#  Cluster 234 ['H-050']
#
#  Cluster 235 ['Mor15u']
#
#  Cluster 236 ['Mor15e']
#
#  Cluster 237 ['Mor15m']
#
#  Cluster 238 ['Hy']
#
#  Cluster 239 ['Mor08m']
#
#  Cluster 240 ['RNCG']
#
#  Cluster 241 ['MATS7m', 'MATS7e']
#
#  Cluster 242 ['R5e+']
#
#  Cluster 243 ['EEig11x']
#
#  Cluster 244 ['PJI2']
#
#  Cluster 245 ['PJI3']
#
#  Cluster 246 ['IVDE']
#
#  Cluster 247 ['IC2']
#
#  Cluster 248 ['EEig10d']
#
#  Cluster 249 ['MATS6m', 'GATS6m']
#
#  Cluster 250 ['R5u+']
#
#  Cluster 251 ['R6u+']
#
#  Cluster 252 ['C-040']
#
#  Cluster 253 ['Mor29m']
#
#  Cluster 254 ['Mor29v']
#
#  Cluster 255 ['G3v']
#
#  Cluster 256 ['Gm']
#
#  Cluster 257 ['G2p']
#
#  Cluster 258 ['EEig08d', 'EEig09d']
#
#  Cluster 259 ['GATS5e']
#
#  Cluster 260 ['GATS5m']
#
#  Cluster 261 ['MATS6e', 'GATS6e']
#
#  Cluster 262 ['DISPm']
#
#  Cluster 263 ['DISPe']
#
#  Cluster 264 ['PCWTe']
#
#  Cluster 265 ['Mor21u']
#
#  Cluster 266 ['Mor21e']
#
#  Cluster 267 ['SIC1']
#
#  Cluster 268 ['CIC1']
#
#  Cluster 269 ['HATS1e']
#
#  Cluster 270 ['Mor13u']
#
#  Cluster 271 ['Mor13e']
#
#  Cluster 272 ['Mor29u']
#
#  Cluster 273 ['R2e']
#
#  Cluster 274 ['Mor10u']
#
#  Cluster 275 ['R1e+']
#
#  Cluster 276 ['R3e+']
#
#  Cluster 277 ['R1u+']
#
#  Cluster 278 ['R3u+']
#
#  Cluster 279 ['Mor10e']
#
#  Cluster 280 ['HATS1u']
#
#  Cluster 281 ['E1e']
#
#  Cluster 282 ['ISH']
#
#  Cluster 283 ['H0u']
#
#  Cluster 284 ['SIC2', 'CIC2']
#
#  Cluster 285 ['IC4']
#
#  Cluster 286 ['SIC4', 'CIC4']
#
#  Cluster 287 ['EEig10r']
#
#  Cluster 288 ['P1m', 'P2m', 'P1s', 'P2s']
#
#  Cluster 289 ['P1u', 'P2u', 'P1v', 'P2v', 'P1e', 'P2e']
#
#  Cluster 290 ['Ku', 'Kv', 'Ke']
#
#  Cluster 291 ['ASP', 'Ks']
#
#  Cluster 292 ['L/Bw']
#
#  Cluster 293 ['MAXDN', 'MAXDP']
#
#  Cluster 294 ['AROM']
#
#  Cluster 295 ['EEig04x']
#
#  Cluster 296 ['Mor18u']
#
#  Cluster 297 ['Mor18e']
#
#  Cluster 298 ['Mor32u']
#
#  Cluster 299 ['RARS', 'REIG']
#
#  Cluster 300 ['Mor26u']
#
#  Cluster 301 ['Mor31u']
#
#  Cluster 302 ['Mor31v']
#
#  Cluster 303 ['MATS1p']
#
#  Cluster 304 ['Mor12u']
#
#  Cluster 305 ['Mor08u']
#
#  Cluster 306 ['GATS4m']
#
#  Cluster 307 ['GATS4e']
#
#  Cluster 308 ['Mor24u']
#
#  Cluster 309 ['Mor14m']
#
#  Cluster 310 ['Mor28v']
#
#  Cluster 311 ['MATS4m']
#
#  Cluster 312 ['MATS4e']
#
#  Cluster 313 ['GATS1m']
#
#  Cluster 314 ['Mor28m']
#
#  Cluster 315 ['AAC']
#
#  Cluster 316 ['Ds']
#
#  Cluster 317 ['E1u']
#
#  Cluster 318 ['R6e+']
#
#  Cluster 319 ['Mor18v']
#
#  Cluster 320 ['Mor09e']
#
#  Cluster 321 ['Mor20u']
#
#  Cluster 322 ['Mor20e']
#
#  Cluster 323 ['Mor09u']
#
#  Cluster 324 ['Ms']
#
#  Cluster 325 ['Qmean']
#
#  Cluster 326 ['Mor12v']
#
#  Cluster 327 ['LDI']
#
#  Cluster 328 ['Mor15v']
#
#  Cluster 329 ['EEig12x']
#
#  Cluster 330 ['EEig12d']
#
#  Cluster 331 ['qpmax']
#
#  Cluster 332 ['qnmax']
#
#  Cluster 333 ['IC1']
#
#  Cluster 334 ['R4e']
#
#  Cluster 335 ['HATS2m']
#
#  Cluster 336 ['RTm+']
#
#  Cluster 337 ['R2m+']
#
#  Cluster 338 ['CIC0']
#
#  Cluster 339 ['BELm4', 'Mor17v']
#
#  Cluster 340 ['BELm2']
#
#  Cluster 341 ['Mor17u']
#
#  Cluster 342 ['Mor17m']
#
#  Cluster 343 ['R4u']
#
#  Cluster 344 ['nC']
#
#  Cluster 345 ['C-001']
#
#  Cluster 346 ['BELe2', 'BELe4']
#
#  Cluster 347 ['RCON']
#
#  Cluster 348 ['Mor22v']
#
#  Cluster 349 ['RDF035v']
#
#  Cluster 350 ['RDF035p']
#
#  Cluster 351 ['RDF035e']
#
#  Cluster 352 ['GATS3m']
#
#  Cluster 353 ['HATS3e', 'R3e']
#
#  Cluster 354 ['HATS3u']
#
#  Cluster 355 ['HATS0e', 'R2v+', 'R4e+']
#
#  Cluster 356 ['HATS2e', 'R2e+']
#
#  Cluster 357 ['H2u']
#
#  Cluster 358 ['RTe+']
#
#  Cluster 359 ['HATS2v', 'HATS4e']
#
#  Cluster 360 ['BELm6']
#
#  Cluster 361 ['Mor11e']
#
#  Cluster 362 ['MATS3v']
#
#  Cluster 363 ['SPAM', 'Mor11u']
#
#  Cluster 364 ['HATS1v']
#
#  Cluster 365 ['BELv4', 'BELe1', 'J3D']
#
#  Cluster 366 ['BELv1']
#
#  Cluster 367 ['X2Av', 'X4Av']
#
#  Cluster 368 ['X5Av']
#
#  Cluster 369 ['R1e']
#
#  Cluster 370 ['TE2']
#
#  Cluster 371 ['H1u']
#
#  Cluster 372 ['GATS2m']
#
#  Cluster 373 ['MATS3e']
#
#  Cluster 374 ['GATS3e']
#
#  Cluster 375 ['GATS2e']
#
#  Cluster 376 ['Du']
#
#  Cluster 377 ['R1u']
#
#  Cluster 378 ['HATS1p']
#
#  Cluster 379 ['HATS2p']
#
#  Cluster 380 ['HATS0p', 'RTp+']
#
#  Cluster 381 ['HATS0m']
#
#  Cluster 382 ['R1v']
#
#  Cluster 383 ['R1p']
#
#  Cluster 384 ['Mor04m']
#
#  Cluster 385 ['Mor24m']
#
#  Cluster 386 ['Mor31m']
#
#  Cluster 387 ['X0Av', 'X3Av']
#
#  Cluster 388 ['Mor09v']
#
#  Cluster 389 ['R2p']
#
#  Cluster 390 ['Mor20m', 'Mor20v']
#
#  Cluster 391 ['MATS3p', 'GATS3v', 'GATS3p']
#
#  Cluster 392 ['Mor09m', 'Mor10v']
#
#  Cluster 393 ['Mor11p']
#
#  Cluster 394 ['Mor18m']
#
#  Cluster 395 ['MATS2e']
#
#  Cluster 396 ['Mor02m']
#
#  Cluster 397 ['Mor11m', 'Mor11v']
#
#  Cluster 398 ['RDF025u']
#
#  Cluster 399 ['RDF020m']
#
#  Cluster 400 ['Mor07m', 'Mor12m']
#
#  Cluster 401 ['Mor13v']
#
#  Cluster 402 ['Mor02v', 'Mor02e']
#
#  Cluster 403 ['Mor19m']
#
#  Cluster 404 ['Mor19v']
#
#  Cluster 405 ['BELm5']
#
#  Cluster 406 ['RDF035u']
#
#  Cluster 407 ['R4v+', 'R4p+']
#
#  Cluster 408 ['R4m+']
#
#  Cluster 409 ['Dp']
#
#  Cluster 410 ['H0p']
#
#  Cluster 411 ['HATS3v', 'R2v']
#
#  Cluster 412 ['HATS4v']
#
#  Cluster 413 ['DISPp', 'R3v+', 'R3p+']
#
#  Cluster 414 ['R5m+', 'R5p+']
#
#  Cluster 415 ['R5v+']
#
#  Cluster 416 ['E1v']
#
#  Cluster 417 ['E1p']
#
#  Cluster 418 ['DISPv']
#
#  Cluster 419 ['MATS6v']
#
#  Cluster 420 ['MATS6p']
#
#  Cluster 421 ['R6m+']
#
#  Cluster 422 ['R6v+']
#
#  Cluster 423 ['R6p+']
#
#  Cluster 424 ['ESpm01d']
#
#  Cluster 425 ['BEHm2']
#
#  Cluster 426 ['ARR']
#
#  Cluster 427 ['Mor07u', 'Mor07e']
#
#  Cluster 428 ['E2u']
#
#  Cluster 429 ['Jhetv']
#
#  Cluster 430 ['GATS5v', 'H3m', 'H3p']
#
#  Cluster 431 ['H4m']
#
#  Cluster 432 ['RDF055v']
#
#  Cluster 433 ['T(Cl..Cl)']
#
#  Cluster 434 ['GATS5p']
#
#  Cluster 435 ['H1v']
#
#  Cluster 436 ['HTp']
#
#  Cluster 437 ['TIE']
#
#  Cluster 438 ['AMW', 'HTm']
#
#  Cluster 439 ['BEHm1', 'Mor06u', 'H2p', 'R5m']
#
#  Cluster 440 ['Mor26m']
#
#  Cluster 441 ['Mor13m']
#
#  Cluster 442 ['HATS5v']
#
#  Cluster 443 ['E2v']
#
#  Cluster 444 ['R4v', 'RTv']
#
#  Cluster 445 ['GATS4v']
#
#  Cluster 446 ['GATS4p']
#
#  Cluster 447 ['RDF030m']
#
#  Cluster 448 ['Mor21m']
#
#  Cluster 449 ['Mor27m']
#
#  Cluster 450 ['Mor23m']
#
#  Cluster 451 ['Mor21v']
#
#  Cluster 452 ['H0m', 'HATSm', 'HATSv']
#
#  Cluster 453 ['T(O..Cl)', 'HATS3m', 'R3v']
#
#  Cluster 454 ['R3m+']
#
#  Cluster 455 ['BELm3', 'Mor10m', 'Mor07v']
#
#  Cluster 456 ['E2p', 'HATS4m']
#
#  Cluster 457 ['Mv', 'RDF045m', 'HATS5m', 'nPhX']
#
#  Cluster 458 ['RDF040v']
#
#  Cluster 459 ['SHP2']
#
#  Cluster 460 ['RDF045v']
#
#  Cluster 461 ['Mor06m', 'H1p']
#
#  Cluster 462 ['GATS2p', 'MLOGP', 'MLOGP2', 'ALOGP', 'BLTD48']
#
#  Cluster 463 ['GATS6v', 'GATS6p']
#
#  Cluster 464 ['R4p', 'RTp']
#
#  Cluster 465 ['GATS2v']
#
#  Cluster 466 ['Dv']
#
#  Cluster 467 ['RDF010v']
#
#  Cluster 468 ['R2m']
#
#  Cluster 469 ['RDF010m']
#
#  Cluster 470 ['Mor02u', 'Mor02p']
#
#  Cluster 471 ['GATS1v', 'GATS1p']
#
#  Cluster 472 ['Mor19u']
#
#  Cluster 473 ['RDF020u']
#
#  Cluster 474 ['E1m']
#
#  Cluster 475 ['R1m+']
#
#  Cluster 476 ['Mor14v']
#
#  Cluster 477 ['R2u']
#
#  Cluster 478 ['HATS1m']
#
#  Cluster 479 ['H0e']
#
#  Cluster 480 ['Dm']
#
#  Cluster 481 ['SIC0']
#
#  Cluster 482 ['HATSe']
#
#  Cluster 483 ['Mor16m']
#
#  Cluster 484 ['Mor16v']
#
#  Cluster 485 ['Mor16u']
#
#  Cluster 486 ['Mor26v', 'R1m']
#
#  Cluster 487 ['Mor14u']
#
#  Cluster 488 ['Mor28u']
#
#  Cluster 489 ['MATS5v']
#
#  Cluster 490 ['MATS5p']
#
#  Cluster 491 ['MATS1v']
#
#  Cluster 492 ['Mor22m']
#
#  Cluster 493 ['RDF035m']

# %%
# this is the important diagnostic for the method:
# if you have chosen good parameters above
# then this histogram will show a smooth curvature 
# resembling either a pareto or skewed gaussian
clust.cluster_dist()

# %%
# let's try single-threaded feature selection 
# giving training set, clusterinfo, and number of components to select for 
# model is either regression or classification
# learning is number of total epochs to train
# bank is number a memory of best models filtered 
# interval is how often you want updates on progress
# the system returns a list of features it found were best

# this is a small data set, so smaller bank and intervals are used to show convergence
features = fss.mlr_selection(xtrain, ytrain, clusterinfo, 2, model="regression", learning=150, bank=50, interval=10)
# Out:
# Start time:  11:43:20
#  Regression
# 10 => 11:43:20 [0.5646699236881829, ['R2m', 'X2Av']]
# 20 => 11:43:21 [0.6583947897894367, ['Mor04u', 'X2Av']]
# 30 => 11:43:21 [0.6583947897894367, ['Mor04u', 'X2Av']]
# 40 => 11:43:22 [0.7742657151910233, ['Mor04u', 'X5Av']]
# 50 => 11:43:22 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 60 => 11:43:22 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 70 => 11:43:23 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 80 => 11:43:23 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 90 => 11:43:24 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 100 => 11:43:24 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 110 => 11:43:25 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 120 => 11:43:25 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 130 => 11:43:26 [0.7932755997633875, ['RDF070v', 'X5Av']]
# 140 => 11:43:26 [0.7932755997633875, ['RDF070v', 'X5Av']]
# Best score:  0.7932755997633875
# Model's cluster info [104, 368]
# Finish Time :  11:43:26

# %%
# we can export this model for now 
model1 = em.ModelExport(xtrain, ytrain, xtest, ytest, features)
# show summary data 
model1.mlr()
# Out:
# Model features:  ['RDF070v', 'X5Av']
# Coefficients:  [ -1.45342979 -96.40117135]
# Intercept:  -0.07684397375001017
# RMSE: 0.250852
# R^2: 0.793276

# %%
# show plot of training
model1.train_plot()

# %%
model1.williams_plot()
# Out:
# 22

# %%
model1.external_set()
# Out:
# R2 0.7932755997633875
# Q2 0.7099699197171891
# RMSE 0.2508516645820539
# coef [ -1.45342979 -96.40117135]
# intercept -0.07684397375001017

# %%
model1.model_corr()

# %%
# for some n number of points: default to 1000
model1.y_scrambling(n=1000)

# %%
model1.scores(verbose=True)
# Out:
# RMSE : 0.2508516645820539
# RMSE External : 0.3291162069672103
# R2 : 0.7932755997633875
# Q2 : 0.7099699197171891
# Q2F1 : 0.7138880300214392
# Q2F2 : 0.7106827057393145
# Q2F3 : 0.9978028024221
# CCC : 0.9007449089766993
# {'RMSE': 0.2508516645820539,
#  'RMSE External': 0.3291162069672103,
#  'R2': 0.7932755997633875,
#  'Q2': 0.7099699197171891,
#  'Q2F1': 0.7138880300214392,
#  'Q2F2': 0.7106827057393145,
#  'Q2F3': 0.9978028024221,
#  'CCC': 0.9007449089766993}

# %%
model1.mlr()
# Out:
# Model features:  ['RDF070v', 'X5Av']
# Coefficients:  [ -1.45342979 -96.40117135]
# Intercept:  -0.07684397375001017
# RMSE: 0.250852
# R^2: 0.793276

# %%
model1.p_value_plot()

# %%
model1.feature_importance_plot()

# %%
cv.cross_validation(dfx, dfy, ['RDF070v', 'X5Av'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cv.cross_validation(dfx, dfy, ['RDF070v', 'X5Av'])
#
# File ~/projects/pyQSARplus/cross_validation.py:63, in cross_validation.__init__(self, X_data, y_data, feature_set)
#      61 self.original_q2 = q2_score(self.y, self.mlr.predict(self.x))
#      62 self.xx = np.concatenate((self.x))
# ---> 63 self.yy = np.concatenate((self.y))
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated
